# %%
# Set to have less messages from distributed
import dask
dask.config.set({"logging.distributed": "error"})
dask.config.set(fuse_ave_width=2)

# %%
# Setup cluster
from dask.distributed import Client, progress
from dask_kubernetes import KubeCluster
cluster = KubeCluster()
cluster.adapt(minimum=1, maximum=20)
client = Client(cluster)
client
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/distributed/dashboard/core.py:72: UserWarning:
# Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the diagnostics dashboard on a random port instead.
#   warnings.warn("\n" + msg)
# <Client: 'tcp://10.32.10.8:41157' processes=0 threads=0, memory=0 B>

# %%
# Load some useful modules 
import numpy as np
import xarray as xr
import xrft
import intake

from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/intake/source/discovery.py:136: FutureWarning: The drivers ['geojson', 'postgis', 'shapefile', 'spatialite'] do not specify entry_points and were only discovered via a package scan. This may break in a future release of intake. The packages should be updated.
#   FutureWarning)

# %%
cat_url = "https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/ocean/llc4320.yaml"
cat = intake.Catalog(cat_url)

# %%
coords = cat.LLC4320_grid(chunks=False).to_dask().isel(face=1).reset_coords()

# %%
coords = coords.chunk({'time':1})

# %%
sss = cat.LLC4320_SSS().to_dask().isel(face=1, 
                                i = slice(0,200), j = slice(0,200))

# %%
sss.SSS.data
# Out:
# dask.array<getitem, shape=(9030, 200, 200), dtype=float32, chunksize=(1, 200, 200), chunktype=numpy.ndarray>

# %%
sss = sss.SSS.chunk({'time': 360, 'i':200, 'j':200})

# %%
sss.data
# Out:
# dask.array<rechunk-merge, shape=(9030, 200, 200), dtype=float32, chunksize=(360, 200, 200), chunktype=numpy.ndarray>

# %%
subset_factor = 20
sss_sub = (sss.isel(j=slice(0 ,None, subset_factor),
                              i=slice(0 ,None, subset_factor), 
                              time=slice(0,120*24))
                 .stack(point=['i','j'])
                 .chunk({'time': 360, 'point':100}))

# %%
sss_sub.data
# Out:
# dask.array<reshape, shape=(2880, 100), dtype=float32, chunksize=(360, 100), chunktype=numpy.ndarray>

# %%
SSS_ps_t = xrft.power_spectrum(sss_sub, dim=['time'],
                           window=True, detrend='constant',
                           chunks_to_segments=True)

# %%
SSS_ps_t.data
# Out:
# dask.array<truediv, shape=(8, 360, 100), dtype=float64, chunksize=(1, 360, 100), chunktype=numpy.ndarray>

# %%
# %time SSS_ps_t.load()

# %%
SSS_ps_t.mean(['time_segment','point']).plot()
plt.xscale('log')
plt.yscale('log')
